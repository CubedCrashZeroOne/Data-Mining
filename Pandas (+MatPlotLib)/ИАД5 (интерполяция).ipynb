# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/mono_trend.csv')
data
# Out:
#     Param1  Param2  Param3     Param4  Param5     Param6
# 0      1.0   100.0     9.0   1.105171     0.1   1.105171
# 1      2.0    99.0     6.0   1.221403     0.2   1.221403
# 2      3.0    98.0     9.0   1.349859     0.3   1.349859
# 3      4.0    97.0     9.0   1.491825     0.4   1.491825
# 4      5.0    96.0     9.0   1.648721     0.5   1.648721
# 5      6.0    95.0     9.0   1.822119     0.6   1.822119
# 6      7.0    94.0     9.0   2.013753     0.7   2.013753
# 7      8.0    93.0     7.0   2.225541     0.8   2.225541
# 8      9.0    92.0     9.0   2.459603     0.9   2.459603
# 9     10.0    91.0     7.0   2.718282     1.0   2.718282
# 10    11.0    90.0     8.0   3.004166     1.1   3.004166
# 11    12.0    89.0     5.0   3.320117     1.2   3.320117
# 12    13.0    88.0     9.0   3.669297     1.3   3.669297
# 13    14.0    87.0    10.0   4.055200     1.4   4.055200
# 14    15.0    86.0    10.0   4.481689     1.5   4.481689
# ...

# %%
data.Param1[:18].is_monotonic_increasing
# Out:
# True

# %%
data.Param1.interpolate(method="linear", inplace=True)
data
# Out:
#     Param1  Param2  Param3     Param4  Param5     Param6
# 0      1.0   100.0     9.0   1.105171     0.1   1.105171
# 1      2.0    99.0     6.0   1.221403     0.2   1.221403
# 2      3.0    98.0     9.0   1.349859     0.3   1.349859
# 3      4.0    97.0     9.0   1.491825     0.4   1.491825
# 4      5.0    96.0     9.0   1.648721     0.5   1.648721
# 5      6.0    95.0     9.0   1.822119     0.6   1.822119
# 6      7.0    94.0     9.0   2.013753     0.7   2.013753
# 7      8.0    93.0     7.0   2.225541     0.8   2.225541
# 8      9.0    92.0     9.0   2.459603     0.9   2.459603
# 9     10.0    91.0     7.0   2.718282     1.0   2.718282
# 10    11.0    90.0     8.0   3.004166     1.1   3.004166
# 11    12.0    89.0     5.0   3.320117     1.2   3.320117
# 12    13.0    88.0     9.0   3.669297     1.3   3.669297
# 13    14.0    87.0    10.0   4.055200     1.4   4.055200
# 14    15.0    86.0    10.0   4.481689     1.5   4.481689
# ...

# %%
data.Param2[:16].is_monotonic_decreasing
# Out:
# True

# %%
data.Param2.interpolate(method="linear", inplace=True)
data
# Out:
#     Param1  Param2  Param3     Param4  Param5     Param6
# 0      1.0   100.0     9.0   1.105171     0.1   1.105171
# 1      2.0    99.0     6.0   1.221403     0.2   1.221403
# 2      3.0    98.0     9.0   1.349859     0.3   1.349859
# 3      4.0    97.0     9.0   1.491825     0.4   1.491825
# 4      5.0    96.0     9.0   1.648721     0.5   1.648721
# 5      6.0    95.0     9.0   1.822119     0.6   1.822119
# 6      7.0    94.0     9.0   2.013753     0.7   2.013753
# 7      8.0    93.0     7.0   2.225541     0.8   2.225541
# 8      9.0    92.0     9.0   2.459603     0.9   2.459603
# 9     10.0    91.0     7.0   2.718282     1.0   2.718282
# 10    11.0    90.0     8.0   3.004166     1.1   3.004166
# 11    12.0    89.0     5.0   3.320117     1.2   3.320117
# 12    13.0    88.0     9.0   3.669297     1.3   3.669297
# 13    14.0    87.0    10.0   4.055200     1.4   4.055200
# 14    15.0    86.0    10.0   4.481689     1.5   4.481689
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x="Param1", y="Param3")

# %%
data.Param3.interpolate(method="linear", inplace=True)
data
# Out:
#     Param1  Param2  Param3     Param4  Param5     Param6
# 0      1.0   100.0     9.0   1.105171     0.1   1.105171
# 1      2.0    99.0     6.0   1.221403     0.2   1.221403
# 2      3.0    98.0     9.0   1.349859     0.3   1.349859
# 3      4.0    97.0     9.0   1.491825     0.4   1.491825
# 4      5.0    96.0     9.0   1.648721     0.5   1.648721
# 5      6.0    95.0     9.0   1.822119     0.6   1.822119
# 6      7.0    94.0     9.0   2.013753     0.7   2.013753
# 7      8.0    93.0     7.0   2.225541     0.8   2.225541
# 8      9.0    92.0     9.0   2.459603     0.9   2.459603
# 9     10.0    91.0     7.0   2.718282     1.0   2.718282
# 10    11.0    90.0     8.0   3.004166     1.1   3.004166
# 11    12.0    89.0     5.0   3.320117     1.2   3.320117
# 12    13.0    88.0     9.0   3.669297     1.3   3.669297
# 13    14.0    87.0    10.0   4.055200     1.4   4.055200
# 14    15.0    86.0    10.0   4.481689     1.5   4.481689
# ...

# %%
data.plot(x="Param1", y="Param3")

# %%
data.plot(x="Param5", y="Param4")

# %%
data.Param4.interpolate(method="linear", inplace=False).plot(x="Param5", y="Param4")
#Если присмотреться, там линия прямая на одном участке

# %%
data.Param4.interpolate(method="polynomial", order=2, inplace=True)

# %%
data.plot(x="Param5", y="Param4")
