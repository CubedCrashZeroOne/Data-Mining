# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# 1. Загрузіть дані з файлів americas_2011.csv, americas_2012.csv, asia_2000_2015.csv у відповідні
# датафреми df_11, df_12, df_as.

# %%
df_11 = pd.read_csv('/content/drive/MyDrive/americas_2011.csv.csv')
df_12 = pd.read_csv('/content/drive/MyDrive/americas_2012.csv.csv')
df_as = pd.read_csv('/content/drive/MyDrive/asia_2000_2015.csv.csv')

# %% [markdown]
# 2. Виконайте конкатенацію датафреймів df_11 та df_12 таким чином, щоб отримати наступні
# результати:

# %%
df_11=df_11.set_index("Country")
df_12=df_12.set_index("Country")
df_as=df_as.set_index("Country")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
result1 = pd.concat({'2011': df_11, '2012': df_12}, axis=0)
result1
# Out:
#                 2011    2012
#      Country
# 2011 Canada   1700.0     NaN
#      Chile    2047.4     NaN
#      Mexico   2250.2     NaN
#      USA      1786.0     NaN
# 2012 Canada      NaN  1713.0
#      Chile       NaN  2024.0
#      Mexico      NaN  2225.8
#      USA         NaN  1789.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
result2 = pd.concat([df_11, df_12], ignore_index=True)
result2
# Out:
#      2011    2012
# 0  1700.0     NaN
# 1  2047.4     NaN
# 2  2250.2     NaN
# 3  1786.0     NaN
# 4     NaN  1713.0
# 5     NaN  2024.0
# 6     NaN  2225.8
# 7     NaN  1789.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
result3 = pd.concat([df_11, df_12], axis=1)
result3
# Out:
#            2011    2012
# Country
# Canada   1700.0  1713.0
# Chile    2047.4  2024.0
# Mexico   2250.2  2225.8
# USA      1786.0  1789.0

# %% [markdown]
# 3. Виконайте конкатенацію датафреймів result_am та df_as для отримання наступного результату:
# ![image.png](data:image/png;base64,...)

# %%
pd.concat({'Asia': df_as, 'America': result3}, axis=0)
# Out:
#                    2000    2001    2002    2003    2004    2005    2006  \
#         Country
# Asia    Israel   2017.0  1979.0  1993.0  1974.0  1942.0  1931.0  1919.0
#         Japan    1821.0  1809.0  1798.0  1799.0  1787.0  1775.0  1784.0
#         Korea    2512.0  2499.0  2464.0  2424.0  2392.0  2351.0  2346.0
#         Russia   1982.0  1980.0  1982.0  1993.0  1993.0  1989.0  1998.0
# America Canada      NaN     NaN     NaN     NaN     NaN     NaN     NaN
#         Chile       NaN     NaN     NaN     NaN     NaN     NaN     NaN
#         Mexico      NaN     NaN     NaN     NaN     NaN     NaN     NaN
#         USA         NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                    2007    2008    2009    2010    2011    2012    2013  \
#         Country
# Asia    Israel   1931.0  1929.0  1927.0  1918.0  1920.0  1910.0  1867.0
#         Japan    1785.0  1771.0  1714.0  1733.0  1728.0  1745.0  1734.0
# ...

# %% [markdown]
# 4. Виконайте конкатенацію датафреймів result_am та df_as для отримання наступного результату:
#
# ![image.png](data:image/png;base64,...)

# %%
pd.concat([df_as, result3], axis=0, join="inner")
# Out:
#            2011    2012
# Country
# Israel   1920.0  1910.0
# Japan    1728.0  1745.0
# Korea    2090.0  2163.0
# Russia   1979.0  1982.0
# Canada   1700.0  1713.0
# Chile    2047.4  2024.0
# Mexico   2250.2  2225.8
# USA      1786.0  1789.0
