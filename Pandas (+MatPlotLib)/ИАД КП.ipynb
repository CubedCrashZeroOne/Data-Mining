# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Видаліть рядки, які містять дублювання. Парний варіант – повне
# дублювання.

# %%
data1 = pd.read_csv("/content/drive/MyDrive/IAD CP/1.csv")
data1
# Out:
#     Param1  Param2  Param3
# 0        1       1      10
# 1       14      14      20
# 2        1       1      10
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 7        1       1      10
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 13      14      14     140
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 21      14      14     220
# 22      23      45     230
# 23       1       1      10
# 24      25      49     250
# 25      26      51     260
# 26      27      53     270
# 27      28      55     280
# 28      29      57     290
# 29      30      59     300
# 30      31      61     310
# 31      32      63     320
# 32      14      14     330

# %%
data1.drop_duplicates()
# Out:
#     Param1  Param2  Param3
# 0        1       1      10
# 1       14      14      20
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 13      14      14     140
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 21      14      14     220
# 22      23      45     230
# 24      25      49     250
# 25      26      51     260
# 26      27      53     270
# 27      28      55     280
# 28      29      57     290
# 29      30      59     300
# 30      31      61     310
# 31      32      63     320
# 32      14      14     330

# %% [markdown]
# 2. Заповніть відсутні значення у числових рядах. Парний варіант –
# середнім значенням ряду.

# %%
data2 = pd.read_csv("/content/drive/MyDrive/IAD CP/2.csv")
data2
# Out:
#       Param1    Param2    Param3
# 0        NaN       NaN  0.368829
# 1   0.745324  0.741975  0.006857
# 2        NaN       NaN  0.577855
# 3        NaN  0.554144       NaN
# 4   0.361776  0.047783  0.910802
# 5        NaN  0.386904  0.898589
# 6   0.296114       NaN       NaN
# 7   0.548682  0.937029  0.623296
# 8        NaN  0.476192  0.601239
# 9   0.212988       NaN       NaN
# 10       NaN  0.550145  0.401912
# 11  0.489422       NaN  0.542035
# 12  0.807206  0.059351  0.253499
# 13       NaN  0.836629  0.254970
# 14  0.668358  0.573262       NaN
# 15       NaN  0.338955  0.542480
# 16  0.481983       NaN       NaN
# 17       NaN  0.662595  0.553173
# 18  0.029959       NaN  0.512285
# 19  0.402025  0.228412       NaN
# 20       NaN       NaN  0.676931
# 21  0.826903  0.315103  0.049497
# 22  0.972243       NaN       NaN
# 23       NaN  0.826348  0.329450
# 24       NaN       NaN  0.484621
# 25  0.546426  0.495242       NaN
# 26  0.994159       NaN  0.460192
# ...

# %%
data2.mean()
# Out:
# Param1    0.490310
# Param2    0.554967
# Param3    0.581223
# dtype: float64

# %%
data2.fillna(data2.mean())
# Out:
#       Param1    Param2    Param3
# 0   0.490310  0.554967  0.368829
# 1   0.745324  0.741975  0.006857
# 2   0.490310  0.554967  0.577855
# 3   0.490310  0.554144  0.581223
# 4   0.361776  0.047783  0.910802
# 5   0.490310  0.386904  0.898589
# 6   0.296114  0.554967  0.581223
# 7   0.548682  0.937029  0.623296
# 8   0.490310  0.476192  0.601239
# 9   0.212988  0.554967  0.581223
# 10  0.490310  0.550145  0.401912
# 11  0.489422  0.554967  0.542035
# 12  0.807206  0.059351  0.253499
# 13  0.490310  0.836629  0.254970
# 14  0.668358  0.573262  0.581223
# 15  0.490310  0.338955  0.542480
# 16  0.481983  0.554967  0.581223
# 17  0.490310  0.662595  0.553173
# 18  0.029959  0.554967  0.512285
# 19  0.402025  0.228412  0.581223
# 20  0.490310  0.554967  0.676931
# 21  0.826903  0.315103  0.049497
# 22  0.972243  0.554967  0.581223
# 23  0.490310  0.826348  0.329450
# 24  0.490310  0.554967  0.484621
# 25  0.546426  0.495242  0.581223
# 26  0.994159  0.554967  0.460192
# ...

# %% [markdown]
# 3. Задані два числові ряди. Дослідить перший ряд на наявність
# монотонності, побудуйте графік, оберіть найкращий метод інтерполяції та
# застосуйте його. Побудуйте графік другого ряду та оберіть найдоречніший
# метод інтерполяції.

# %%
data3 = pd.read_csv("/content/drive/MyDrive/IAD CP/3_Even_Парний.csv")
data3
# Out:
#     Param1     Param2
# 0      1.0   1.105171
# 1      2.0   1.221403
# 2      3.0   1.349859
# 3      4.0   1.491825
# 4      5.0   1.648721
# 5      6.0   1.822119
# 6      7.0   2.013753
# 7      8.0   2.225541
# 8      9.0   2.459603
# 9     10.0   2.718282
# 10    11.0   3.004166
# 11    12.0   3.320117
# 12    13.0   3.669297
# 13    14.0   4.055200
# 14    15.0   4.481689
# 15    16.0   4.953032
# 16    17.0   5.473947
# 17    18.0   6.049647
# 18     NaN   6.685894
# 19    20.0        NaN
# 20     NaN   8.166170
# 21    22.0   9.025013
# 22     NaN        NaN
# 23    24.0  11.023176

# %%
data3.Param1[:18].is_monotonic_increasing
# Out:
# True

# %%
data3.Param1.interpolate(method="linear", inplace=True)
data3
# Out:
#     Param1     Param2
# 0      1.0   1.105171
# 1      2.0   1.221403
# 2      3.0   1.349859
# 3      4.0   1.491825
# 4      5.0   1.648721
# 5      6.0   1.822119
# 6      7.0   2.013753
# 7      8.0   2.225541
# 8      9.0   2.459603
# 9     10.0   2.718282
# 10    11.0   3.004166
# 11    12.0   3.320117
# 12    13.0   3.669297
# 13    14.0   4.055200
# 14    15.0   4.481689
# 15    16.0   4.953032
# 16    17.0   5.473947
# 17    18.0   6.049647
# 18    19.0   6.685894
# 19    20.0        NaN
# 20    21.0   8.166170
# 21    22.0   9.025013
# 22    23.0        NaN
# 23    24.0  11.023176

# %%
data3.plot(x="Param1", y="Param2")

# %%
data3.Param2.interpolate(method="polynomial", order=2, inplace=True)

# %%
data3
# Out:
#     Param1     Param2
# 0      1.0   1.105171
# 1      2.0   1.221403
# 2      3.0   1.349859
# 3      4.0   1.491825
# 4      5.0   1.648721
# 5      6.0   1.822119
# 6      7.0   2.013753
# 7      8.0   2.225541
# 8      9.0   2.459603
# 9     10.0   2.718282
# 10    11.0   3.004166
# 11    12.0   3.320117
# 12    13.0   3.669297
# 13    14.0   4.055200
# 14    15.0   4.481689
# 15    16.0   4.953032
# 16    17.0   5.473947
# 17    18.0   6.049647
# 18    19.0   6.685894
# 19    20.0   7.389083
# 20    21.0   8.166170
# 21    22.0   9.025013
# 22    23.0   9.976731
# 23    24.0  11.023176

# %%
data3.plot(x="Param1", y="Param2")

# %% [markdown]
# 4. Задані три числові ряди. Встановіть наявність кореляції. Парний
# варіант – між першим і третім. Знайдіть максимальний елемент у другому стовпчику, якщо Ваш варіант парний.

# %%
data4 = pd.read_csv("/content/drive/MyDrive/IAD CP/4.csv")
data4
# Out:
#     Param1  Param2  Param3
# 0        1      10     200
# 1        2      20     190
# 2        3      30     180
# 3        4      40     170
# 4        5      50     160
# 5        6      60     150
# 6        7      70     140
# 7        8      80     130
# 8        9      90     120
# 9       10     100     110
# 10      11     110     100
# 11      12     120      90
# 12      13     130      80
# 13      14     140      70
# 14      15     150      60
# 15      16     160      50
# 16      17     170      40
# 17      18     180      30

# %%
data4.loc(1)["Param1", "Param3"].corr()
# Out:
#         Param1  Param3
# Param1     1.0    -1.0
# Param3    -1.0     1.0

# %%
data4.Param2.max()
# Out:
# 180

# %% [markdown]
# 5. Застосуйте метод groupby() бібліотеки pandas для пошуку відповіді на
# наступні запитання.
#   Парний варіант:
#     1. Автомобілі якої марки принесли найбільший прибуток?
#     2. Яка форма торгівлі (online або offline) є найбільш прибутковою?

# %%
data5 = pd.read_csv("/content/drive/MyDrive/IAD CP/5.csv")
data5
# Out:
#       Shop        Date    Make   Model  Type  Price  Qty  Income
# 0   online  01.03.2022     BMW     320   car  20000    2   40000
# 1  offline  02.03.2022   Honda  Shadow  bike  12000    3   36000
# 2   online  03.03.2022  Suzuki   Ignis   car  15000    1   15000
# 3  offline  04.03.2022  Toyota   Camry   car  30000    2   60000
# 4   online  05.03.2022     BMW  R-1000  bike  18000    2   36000
# 5  offline  06.03.2022   Honda   Civic   car  20000    3   60000
# 6   online  07.03.2022  Suzuki   GSX-R  bike  16000    2   32000
# 7  offline  08.03.2022     BMW  GS-750  bike  14000    1   14000
# 8   online  09.03.2022   Honda     CBR  bike  12000    2   24000

# %%
data5_1 = data5.groupby("Make").Income.sum() - data5.groupby("Make").Price.sum()
data5_1
# Out:
# Make
# BMW       38000
# Honda     76000
# Suzuki    16000
# Toyota    30000
# dtype: int64

# %%
data5_1.idxmax()
# Out:
# 'Honda'

# %%
data5_2 = data5.groupby("Shop").Income.sum() - data5.groupby("Shop").Price.sum()
data5_2
# Out:
# Shop
# offline    94000
# online     66000
# dtype: int64

# %%
data5_2.idxmax()
# Out:
# 'offline'
