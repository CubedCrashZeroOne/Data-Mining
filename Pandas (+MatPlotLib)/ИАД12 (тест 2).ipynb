# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/new_test.csv')
data
# Out:
#     Make  Type  Mileage  Price
# 0    BMW   car   115000   5555
# 1    BMW  bike    50000   6752
# 2  Honda   car     6000   7329
# 3  Honda  bike    12000   8965

# %% [markdown]
# 1. Средний пробег по марке (GB)

# %%
data.groupby("Make").Mileage.mean()
# Out:
# Make
# BMW      82500.0
# Honda     9000.0
# Name: Mileage, dtype: float64

# %% [markdown]
# 2. Средняя цена по типу (GB)

# %%
data.groupby("Type").Price.mean()
# Out:
# Type
# bike    7858.5
# car     6442.0
# Name: Price, dtype: float64

# %% [markdown]
# 3. Срез строк в новый датафрейм для всех ТС с пробегом больше 12000

# %%
data[data.Mileage > 12000]
# Out:
#   Make  Type  Mileage  Price
# 0  BMW   car   115000   5555
# 1  BMW  bike    50000   6752

# %% [markdown]
# 4. Используйте clip() чтобы получить серию, где цены будут ограничены 5800-8000

# %%
data.Price.clip(5800, 8000)
# Out:
# 0    5800
# 1    6752
# 2    7329
# 3    8000
# Name: Price, dtype: int64

# %% [markdown]
# 5. Суммарный пробег мотоциклов.

# %%
data[data.Type == "bike"].Mileage.sum()
# Out:
# 62000
