# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/duplicates.csv')
data
# Out:
#     Param1  Param2  Param3
# 0        1       1      10
# 1       14      14      20
# 2        1       1      10
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 7        1       1      10
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 13      14      14     140
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 21      14      14     220
# 22      23      45     230
# 23       1       1      10
# 24      25      49     250
# 25      26      51     260
# 26      27      53     270
# 27      28      55     280
# 28      29      57     290
# 29      30      59     300
# 30      31      61     310
# 31      32      63     320
# 32      14      14     330

# %%
data[data.duplicated()]
# Out:
#     Param1  Param2  Param3
# 2        1       1      10
# 7        1       1      10
# 23       1       1      10

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#     Param1  Param2  Param3
# 0        1       1      10
# 1       14      14      20
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 13      14      14     140
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 21      14      14     220
# 22      23      45     230
# 24      25      49     250
# 25      26      51     260
# 26      27      53     270
# 27      28      55     280
# 28      29      57     290
# 29      30      59     300
# 30      31      61     310
# 31      32      63     320
# 32      14      14     330

# %%
data[data.duplicated(["Param1", "Param2"])]
# Out:
#     Param1  Param2  Param3
# 13      14      14     140
# 21      14      14     220
# 32      14      14     330

# %%
data.drop_duplicates(["Param1", "Param2"], inplace=True)
data
# Out:
#     Param1  Param2  Param3
# 0        1       1      10
# 1       14      14      20
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 22      23      45     230
# 24      25      49     250
# 25      26      51     260
# 26      27      53     270
# 27      28      55     280
# 28      29      57     290
# 29      30      59     300
# 30      31      61     310
# 31      32      63     320

# %%
data[data.duplicated("Param1")]
# Out:
# Empty DataFrame
# Columns: [Param1, Param2, Param3]
# Index: []

# %%
data[data.duplicated("Param2")]
# Out:
# Empty DataFrame
# Columns: [Param1, Param2, Param3]
# Index: []

# %%
data[data.duplicated("Param3")]
# Out:
# Empty DataFrame
# Columns: [Param1, Param2, Param3]
# Index: []

# %%
data[data.duplicated(["Param1", "Param3"])]
# Out:
# Empty DataFrame
# Columns: [Param1, Param2, Param3]
# Index: []

# %%
data[data.duplicated(["Param2", "Param3"])]
# Out:
# Empty DataFrame
# Columns: [Param1, Param2, Param3]
# Index: []
