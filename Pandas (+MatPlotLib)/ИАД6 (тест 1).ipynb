# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/task6.csv')
data
# Out:
#     Task11  Task12  Task13  Task21  Task22      Task3
# 0        1       1      10       1      10   1.105171
# 1       14      14      20       2      20   1.221403
# 2        1       1      10       3      30   1.349859
# 3        4       7      40       4      40   1.491825
# 4        5       9      50       5      50   1.648721
# 5        6      11      60       6      60   1.822119
# 6        7      13      70       7      70   2.013753
# 7        1       1      10       8      80   2.225541
# 8        9      17      90       9      90   2.459603
# 9       10      19     100      10     100   2.718282
# 10      11      21     110      11     110   3.004166
# 11      12      23     120      12     120   3.320117
# 12      13      25     130      13     130   3.669297
# 13      14      14     140      14     140   4.055200
# 14      15      29     150      15     150   4.481689
# 15      16      31     160      16     160   4.953032
# ...

# %% [markdown]
# task 1

# %%
data1 = data.loc(1)[:"Task13"]
data1
# Out:
#     Task11  Task12  Task13
# 0        1       1      10
# 1       14      14      20
# 2        1       1      10
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 7        1       1      10
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 13      14      14     140
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 21      14      14     220
# 22      23      45     230
# 23       1       1      10

# %%
data1.drop_duplicates(inplace=True)
data1.drop_duplicates(["Task11", "Task12"], inplace=True)
data1.drop_duplicates(["Task12", "Task13"], inplace=True)
data1.drop_duplicates(["Task11", "Task13"], inplace=True)
data1.drop_duplicates("Task11", inplace=True)
data1.drop_duplicates("Task12", inplace=True)
data1.drop_duplicates("Task13", inplace=True)
data1
# Out:
#     Task11  Task12  Task13
# 0        1       1      10
# 1       14      14      20
# 3        4       7      40
# 4        5       9      50
# 5        6      11      60
# 6        7      13      70
# 8        9      17      90
# 9       10      19     100
# 10      11      21     110
# 11      12      23     120
# 12      13      25     130
# 14      15      29     150
# 15      16      31     160
# 16      17      33     170
# 17      18      35     180
# 18      19      37     190
# 19      20      39     200
# 20      21      41     210
# 22      23      45     230

# %% [markdown]
# task 2

# %%
data2 = data.loc(1)["Task21":"Task22"]
data2
# Out:
#     Task21  Task22
# 0        1      10
# 1        2      20
# 2        3      30
# 3        4      40
# 4        5      50
# 5        6      60
# 6        7      70
# 7        8      80
# 8        9      90
# 9       10     100
# 10      11     110
# 11      12     120
# 12      13     130
# 13      14     140
# 14      15     150
# 15      16     160
# 16      17     170
# 17      18     180
# 18      19     190
# 19      20     200
# 20      21     210
# 21      22     220
# 22      23     230
# 23      24     240

# %%
data2.corr()
# Out:
#         Task21  Task22
# Task21     1.0     1.0
# Task22     1.0     1.0

# %% [markdown]
# task 3

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x="Task21", y="Task3")

# %%
data.Task3.interpolate(method="polynomial", order=2, inplace=True)
data
# Out:
#     Task11  Task12  Task13  Task21  Task22      Task3
# 0        1       1      10       1      10   1.105171
# 1       14      14      20       2      20   1.221403
# 2        1       1      10       3      30   1.349859
# 3        4       7      40       4      40   1.491825
# 4        5       9      50       5      50   1.648721
# 5        6      11      60       6      60   1.822119
# 6        7      13      70       7      70   2.013753
# 7        1       1      10       8      80   2.225541
# 8        9      17      90       9      90   2.459603
# 9       10      19     100      10     100   2.718282
# 10      11      21     110      11     110   3.004166
# 11      12      23     120      12     120   3.320117
# 12      13      25     130      13     130   3.669297
# 13      14      14     140      14     140   4.055200
# 14      15      29     150      15     150   4.481689
# 15      16      31     160      16     160   4.953032
# ...

# %%
data.plot(x="Task21", y="Task3")
