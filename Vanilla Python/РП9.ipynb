# %%
try:
  num = int(input())
  print("чётное" if num % 2 == 0 else "нечётное")
except ValueError:
  print("Не удалось перевести в число")
except BaseException:
  print("Неожиданная ошибка")
# Out:
# ...
# нечётное
