# %% [markdown]
# 4. Определить, встречается ли в строке буква «ш». Определить длину строки. ЕСЛИ строка длиннее 8 символов, ТО выведите строку в обратном случае.

# %%
s = "У лукоморья 123 дуб зеленый 456"

# %%
"ш" in s.lower()
# Out:
# False

# %%
length = len(s)
length
# Out:
# 31

# %%
if length > 8:
  print(s[::-1])
# Out:
# 654 йынелез буд 321 яьромокул У
