# %% [markdown]
# 4. Дано число, введенное с клавиатуры. Определите сумму квадратов нечетных цифр в числе

# %%
num = input()

sum = 0
for n in num:
  if int(n) % 2 != 0:
    sum += int(n)**2

sum
# Out:
# 1234567890
# 165
