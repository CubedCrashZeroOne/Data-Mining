# %% [markdown]
# 1. Подумайте о том, что вы можете сохранить в списке (создайте свой личный
# список).
# Вывести элементы списка с их индексами (подсказка: перечислить список).

# %%
#task 1.

list = ['one', 'two', 'three', 'four', 'five']

for a in list:
  print(str(list.index(a)) + ' - ' + a)
# Out:
# 0 - one
# 1 - two
# 2 - three
# 3 - four
# 4 - five

# %% [markdown]
# 2. Используйте функцию list.index(), чтобы найти индекс произвольного элемента в
# вашем списке.

# %%
#task 2

print(list.index('four'))
# Out:
# 3

# %% [markdown]
# 3. Используйте функцию append(), чтобы добавить новую собаку (в этом примере!)
# в список. Используйте функцию insert(), чтобы добавить новую собаку в начало
# списка.

# %%
#task 3

list.append('six')
list.insert(0, 'zero')

print(list)
# Out:
# ['zero', 'one', 'two', 'three', 'four', 'five', 'six']

# %% [markdown]
# 4. Удаляйте каждый элемент (собаку) из списка по одному, используя каждый из
# четырех методов:
# • Удалить последний элемент из списка и удалить любой элемент, кроме
# последнего (функция рор()).
# • Удалите один элемент по его индексу и один элемент по его значению.
# Распечатайте сообщение о том, что в списке не осталось элементов, и распечатайте
# список, чтобы доказать, что он пуст.

# %%
#task 4

list.pop()
print(list)
list.pop(3)
print(list)
list.remove('one')
print(list)
list.clear()
print(list)
print('the list is clear now')
# Out:
# ['zero', 'one', 'two', 'three', 'four', 'five']
# ['zero', 'one', 'two', 'four', 'five']
# ['zero', 'two', 'four', 'five']
# []
# the list is clear now
