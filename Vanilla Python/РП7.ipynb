# %% [markdown]
# 4. Даны два списка чисел. Посчитайте, сколько чисел содержится одновременно как в первом списке, так и во втором.

# %%
list1 = range(1, 100, 2)

# %%
list2 = range(12, 100, 3)

# %%
inter = frozenset(list1).intersection(list2)
inter
# Out:
# frozenset({15, 21, 27, 33, 39, 45, 51, 57, 63, 69, 75, 81, 87, 93, 99})

# %%
len(inter)
# Out:
# 15
