# %% [markdown]
# 4. Для строки, введенной с клавиатуры, вывести ее первую половину в обратном порядке.

# %%
text = input()
# Out:
# ABCDEFG

# %%
divided = text[len(text)//2-1::-1]
divided
# Out:
# 'CBA'
