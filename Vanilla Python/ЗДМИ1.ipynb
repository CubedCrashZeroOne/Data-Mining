# %% [markdown]
# **EXAMPLES**

# %%
message = "Python is my favorite language!"
print(message)
# Out:
# Python is my favorite language!

# %%
message = "haha jk I only use asm"
print(message)
# Out:
# haha jk I only use asm

# %%
first_name = 'eric'
print(first_name)
print(first_name.title())
print(first_name.upper())
first_name = 'Eric'
print(first_name.lower())
# Out:
# eric
# Eric
# ERIC
# eric

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = first_name + ' ' + last_name
message = full_name.title() + ' ' + "was considered the world's first computer programmer."
print(message)
# Out:
# Ada Lovelace was considered the world's first computer programmer.

# %%
print("Hello everyone!")
print("\tHello everyone!")
print("Hello \teveryone!")
print("Hello everyone!")
print("\nHello everyone!")
print("Hello \neveryone!")
print("\n\n\nHello everyone!")
# Out:
# Hello everyone!
# 	Hello everyone!
# Hello 	everyone!
# Hello everyone!
#
# Hello everyone!
# Hello
# everyone!
#
#
#
# Hello everyone!

# %%
name = ' eric '
print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# eric
#  eric
# eric

# %%
print(3+2)
print(3-2)
print(3*2)
print(3/2)
print(3**2)
standard_order = 2+3*4
print(standard_order)
my_order = (2+3)*4
print(my_order)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 14
# 20

# %%
# This line is a comment.
print("This line is not a comment, it is code.")
# Out:
# This line is not a comment, it is code.

# %%
def thank_you(name):
# This function prints a two-line personalized thank you message.
  print("\nYou are doing good work, %s!" % name)
print("Thank you very much for your efforts on this project.")
thank_you('Adriana')
thank_you('Billy')
thank_you('Caroline')
# Out:
# Thank you very much for your efforts on this project.
#
# You are doing good work, Adriana!
#
# You are doing good work, Billy!
#
# You are doing good work, Caroline!

# %%
def get_number_word(number):
  if number == 1:
    return 'one'
  elif number == 2:
    return 'two'
  elif number == 3:
    return 'three'
    
for current_number in range(0,4):
  number_word = get_number_word(current_number)
  print(current_number, number_word)
# Out:
# 0 None
# 1 one
# 2 two
# 3 three

# %%
students = ['bernice', 'aaron', 'cody']
for student in students:
  print("Hello, " + student.title() + "!")
# Out:
# Hello, Bernice!
# Hello, Aaron!
# Hello, Cody!

# %%
dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
dog = dogs[0]
print(dog.title())
# Out:
# Border Collie

# %%
dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
print("Results for the dog show are as follows:\n")
for index, dog in enumerate(dogs):
  place = str(index)
  print("Place: " + place + " Dog: " + dog.title())
# Out:
# Results for the dog show are as follows:
#
# Place: 0 Dog: Border Collie
# Place: 1 Dog: Australian Cattle Dog
# Place: 2 Dog: Labrador Retriever

# %% [markdown]
# **EXERCISES**

# %%
text = "I'm yo grandpa"

print("My grandpa once said: '" + text + "'")
# Out:
# My grandpa once said: 'I'm yo grandpa'

# %%
name = "oleg"

print(name)
print(name.upper())
print(name.title())
# Out:
# oleg
# OLEG
# Oleg

# %%
first_name = "Oleg"
last_name = "Gusin"

print(first_name + " " + last_name)
# Out:
# Oleg Gusin

# %%
first_name = "Rick"
last_name = "Astley"

sentence = "I admire " + first_name + " " + last_name + " for creating the best music video ever and being a funny person overall"
print(sentence)
# Out:
# I admire Rick Astley for creating the best music video ever and being a funny person overall

# %%
name = "\t\t  Oleg \n\t\t   " 

print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# Oleg
#
# 		  Oleg
# Oleg

# %%
print(1 + 4)
print(2*6)
print(6-3)
print(200/6)
print(10**20)
# Out:
# 5
# 12
# 3
# 33.333333333333336
# 100000000000000000000

# %%
print(2+2*2)
print((2+2)*2)
# Out:
# 6
# 8
